# %% [markdown]
# 1) Write a Python program to find sum of elements in list?

# %%
import logging
logging.basicConfig(filename = "test1.log", level = logging.INFO , format = '%(asctime)s %(levelname)s %(message)s')
class test():

    def __init__(self,a):
        self.a = a
        
    
    '''Getting the summation of the list'''    
    def summation(self):
        logging.info("Enter list is  {}".format(self.a))
        if type(self.a)==list:
            j = sum(self.a)
            logging.info("Summation of list is {}".format(j))
        else:
            logging.info("Please provide a list")
            
    '''Getting the multiplication of the list'''
    def multiplication(self):
        list1 = 1
        for i in range(0,len(self.a)):
            list1 = self.a[i]*list1
        logging.info("Multiplication of list is {}".format(list1))
    
    '''Smallest number of the list'''
    def smallest(self):
        d = min(self.a)
        logging.info("Minimum of list is {}".format(d))
    
    '''Largest number of the list'''
    def largest(self):
        e = max(self.a)
        logging.info("Largest number  of list is {}".format(e))
    
    '''Second largest number of the list'''
    def second_largest(self):
        f = self.a
        f.sort(reverse=True)
        
        logging.info("Second largest number  of the list is {}".format(f[1]))
    
    '''Nth largest number'''
    def N_largest(self):
        try:
            g = int(input("Enter the number "))
        except Exception as e:
            print("Error"+ str(e))
        else:
            if g >len(self.a):
                print("invalid nuber")
            else:
                h = self.a
                h.sort(reverse=True)
                print(h)
                
                print(h[g-1])
    
    '''Getting the even number from list'''
    def even_numbers(self):
        list2 = []
        for i in self.a:
            if i%2==0:
                list2.append(i)
        print(list2)
        
    '''Getting odd number from the list'''
    def odd_numbers(self):
        list3 = []
        for i in self.a:
            if i%2!=0:
                list3.append(i)
        print(list3)
    
    '''Remove empty list from the list'''
    def remove_empty_list(self):
        h = [i for i in self.a if i!=[]]
        print(h)
        
    '''Copy of list'''
    def copy(self):
        j =self.a.copy()
        print(j)
        
    '''Count of element of a list in dictionary'''
    def element_count(self):
        dict1= {}
        m = []
        for i in self.a:
            if i not in m:
                m.append(i)
        for j in m:
            dict1[j]=self.a.count(j)
        print(dict1)
